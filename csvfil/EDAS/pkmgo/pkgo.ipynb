# %%
# 9/18/2025

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pokemon_go.csv')

# %%
print(f'rown and columns: {df.shape}')
# Out:
# rown and columns: (75, 27)

# %%
print(f'first x rows {df.head()}')
# Out:
# first x rows       name species   cp  hp  weight  height  power_up_stardust  \
# 0  Pidgey1  Pidgey  384  56    2.31    0.34               2500
# 1  Pidgey2  Pidgey  366  54    1.67    0.29               2500
# 2  Pidgey3  Pidgey  353  55    1.94    0.30               3000
# 3  Pidgey4  Pidgey  338  51    1.73    0.31               3000
# 4  Pidgey5  Pidgey  242  45    1.44    0.27               1900
#
#    power_up_candy   attack_weak attack_weak_type  ...  height_new  \
# 0               2        Tackle           Normal  ...        1.24
# 1               2  Quick Attack           Normal  ...        1.05
# 2               3  Quick Attack           Normal  ...        1.11
# 3               3        Tackle           Normal  ...        1.12
# 4               2  Quick Attack           Normal  ...        0.98
#
#   power_up_stardust_new power_up_candy_new  attack_weak_new  \
# 0                  2500                  2       Steel Wing
# ...

# %%
print(f'column n data types: {df.dtypes}')
# Out:
# column n data types: name                        object
# species                     object
# cp                           int64
# hp                           int64
# weight                     float64
# height                     float64
# power_up_stardust            int64
# power_up_candy               int64
# attack_weak                 object
# attack_weak_type            object
# attack_weak_value            int64
# attack_strong               object
# attack_strong_type          object
# attack_strong_value          int64
# cp_new                       int64
# hp_new                       int64
# weight_new                 float64
# height_new                 float64
# power_up_stardust_new        int64
# power_up_candy_new           int64
# attack_weak_new             object
# attack_weak_type_new        object
# attack_weak_value_new        int64
# attack_strong_new           object
# attack_strong_type_new      object
# attack_strong_value_new      int64
# ...

# %%
print(f'data frame: {df.info()}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     75 non-null     object
#  1   species                  75 non-null     object
#  2   cp                       75 non-null     int64
#  3   hp                       75 non-null     int64
#  4   weight                   75 non-null     float64
#  5   height                   75 non-null     float64
#  6   power_up_stardust        75 non-null     int64
#  7   power_up_candy           75 non-null     int64
#  8   attack_weak              75 non-null     object
#  9   attack_weak_type         75 non-null     object
#  10  attack_weak_value        75 non-null     int64
#  11  attack_strong            75 non-null     object
#  12  attack_strong_type       75 non-null     object
#  13  attack_strong_value      75 non-null     int64
# ...

# %%
print(df.isnull().sum())
# Out:
# name                        0
# species                     0
# cp                          0
# hp                          0
# weight                      0
# height                      0
# power_up_stardust           0
# power_up_candy              0
# attack_weak                 0
# attack_weak_type            0
# attack_weak_value           0
# attack_strong               0
# attack_strong_type          0
# attack_strong_value         0
# cp_new                      0
# hp_new                      0
# weight_new                  0
# height_new                  0
# power_up_stardust_new       0
# power_up_candy_new          0
# attack_weak_new             0
# attack_weak_type_new        0
# attack_weak_value_new       0
# attack_strong_new           0
# attack_strong_type_new      0
# attack_strong_value_new     0
# notes                      68
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     75 non-null     object
#  1   species                  75 non-null     object
#  2   cp                       75 non-null     int64
#  3   hp                       75 non-null     int64
#  4   weight                   75 non-null     float64
#  5   height                   75 non-null     float64
#  6   power_up_stardust        75 non-null     int64
#  7   power_up_candy           75 non-null     int64
#  8   attack_weak              75 non-null     object
#  9   attack_weak_type         75 non-null     object
#  10  attack_weak_value        75 non-null     int64
#  11  attack_strong            75 non-null     object
#  12  attack_strong_type       75 non-null     object
#  13  attack_strong_value      75 non-null     int64
# ...

# %%
plt.figure(figsize=(6,6))
sns.histplot(df['cp'], bins=15, kde=True, color='green')
plt.title('distro of combat power')
plt.xlabel('cp')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='attack_strong_type', data=df, order=df['attack_strong_type'].value_counts().index)
plt.title('Cnt of Strong Attack Types')
plt.xticks(rotation=4)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='weight', y='cp', data=df, hue='species')
plt.title('CP vs Weight')
plt.xlabel('Weight')
plt.ylabel('CP')
plt.show()

# %%
# hp vs weight
plt.figure(figsize=(7,5))

sns.scatterplot(x='weight', y='hp', data=df, hue='species')

plt.title('hp  to weight')
plt.xlabel('Weight')
plt.ylabel('hp')
plt.show()

# %%
# hp vs weight. regression
plt.figure(figsize=(7,5))

sns.regplot(x='weight', y='hp', data=df, scatter_kws={'alpha':0.6}, line_kws={'color':'green'})

plt.title('hp  to weight')
plt.xlabel('Weight')
plt.ylabel('hp')
plt.show()

# %%
from scipy.stats import pearsonr

corr, p_value = pearsonr(df['hp'], df['weight'])
print(f'Pearson correlation: {corr:.2f}, p-value: {p_value:.3f}')
# Out:
# Pearson correlation: 0.46, p-value: 0.000
