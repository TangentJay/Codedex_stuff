# %%
#july 4 2026
error = 50
while error > 1:
    error = error / 4
    print(error)
# Out:
# 12.5
# 3.125
# 0.78125

# %%
import random
num = random.randint(1,100)
if num % 2 == 0:
    print(f' {num}  is divisible by 2')
elif num % 3 == 0: 
    print(f' {num} is divisibly by 3')
else:
    print(num)
# Out:
#  4  is divisible by 2

# %%
items = ['bob','also','into',1337]
for i in range(0, len(items)):
    print(items[i])
# Out:
# bob
# also
# into
# 1337
