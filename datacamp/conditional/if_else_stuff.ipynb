# %% [markdown]
# 6/27/2026 if else stuff

# %% [markdown]
# Is z even

# %%
z =[ 420, 421, 422, 423] 
for z in z:
    if z % 2 == 0: print (f'{z} is even') 
    else: print(f'{z} is odd')
# Out:
# 420 is even
# 421 is odd
# 422 is even
# 423 is odd

# %%
area = 10.0
if (area < 9) :
    print("small")
elif (area <12):
    print('medium')
else: print('Large')
# Out:
# medium
