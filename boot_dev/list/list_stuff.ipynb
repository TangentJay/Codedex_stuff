# %%
#7/9/2026
trees = ['oak', 'pine', 'maple']

for tree in trees:
    print(tree, trees)
# Out:
# oak ['oak', 'pine', 'maple']
# pine ['oak', 'pine', 'maple']
# maple ['oak', 'pine', 'maple']

# %%
#7/9/2026
trees = ['oak', 'pine', 'maple']

for i in trees:
    print(i)
    if i =='oak':
        print('yo, oak')
    else: print('no oak')
# Out:
# oak
# yo, oak
# pine
# no oak
# maple
# no oak

# %%
#7/9/2026
trees = ['oak', 'pine', 'maple']

for i in range(0, len(trees)):
    print(i, trees)
# Out:
# 0 ['oak', 'pine', 'maple']
# 1 ['oak', 'pine', 'maple']
# 2 ['oak', 'pine', 'maple']

# %%
#code more list
fruits =['apple', 'orange']
for fruit in fruits:
    print(fruits)
# Out:
# ['apple', 'orange']
# ['apple', 'orange']

# %%
print(float('inf'))
# Out:
# inf
