# %%
#7/9/2026
trees = ['oak', 'pine', 'maple']

for tree in trees:
    print(tree)
# Out:
# oak
# pine
# maple

# %%
#7/9/2026
trees = ['oak', 'pine', 'maple']

for i in trees:
    print(i)
    if i =='oak':
        print('yo, oak')
    else: print('no oak')
# Out:
# oak
# yo, oak
# pine
# no oak
# maple
# no oak
